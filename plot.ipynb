# %%
import os
from utils.misc import results_dir
from utils.plot import ProcessResults

base_dir = os.path.join(results_dir(), 'set_01', 'conv_4_exp_1')
num_trials = 3

data = ProcessResults(base_dir, num_trials)
data.plot_train_log()
# Out:
# Accuracy vs training epochs.

# %%
data.plot_spar_acc()
# Out:
# Accuracy vs sparsity when retrained.

# %%
data.plot_lth()
# Out:
# Results for real
# Results for quat
